# %%
import tensorflow as tf

import matplotlib.pyplot as plt
import numpy as np

from time import time

# to plot pretty histograms
import seaborn as sns
import pandas as pd

from sde.sde_learning_network import \
    (
        SDEIdentification,
        ModelBuilder,
        SDEApproximationNetwork,
    )

from sde.experiment_reports import \
(
    sample_data,
    plot_results_functions,
    generate_results,
    plot_results_1d,
    probability_density
)

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# notebook parameters
random_seed = 1
step_size = 1e-2  # step size
n_pts = 10000        # number of points

n_layers = 2
n_dim_per_layer = 50

ACTIVATIONS = tf.nn.elu
VALIDATION_SPLIT = .1
BATCH_SIZE = 32
N_EPOCHS = 250

xlim = [-2, 2]

# only diagonal, but we are in 1D so it does not matter anyway
diffusivity_type = "diagonal"

tf.random.set_seed(random_seed)

# %%
# EXAMPLE 1
def true_drift(x):
    return -(4*x**3 - 2*4*x+3)/2 # negative derivative of the potential

def true_diffusivity(x):
    return (1e-1*x+1)*0.5

def true_drift_diffusivity(x):
    return true_drift(x), true_diffusivity(x)

def sample_nd_data(n_dimensions, _rng, print_results=False, increase_n_points=False):
    if increase_n_points:
        _n_pts = n_pts * n_dimensions
    else:
        _n_pts = n_pts
    x_data, y_data = sample_data(true_drift_diffusivity,
                                 step_size=step_size, n_dimensions=n_dimensions,
                                 low=xlim[0], high=xlim[1], n_pts=_n_pts,
                                 rng=_rng)
    if print_results:
        print('data shape', x_data.shape)

    step_sizes = np.zeros((x_data.shape[0],)) + step_size
    return x_data, y_data, step_sizes

# %%
# define the neural network model we will use for identification
def define_nd_model(n_dimensions):
    encoder = ModelBuilder.define_gaussian_process(
                                            n_input_dimensions=n_dimensions,
                                            n_output_dimensions=n_dimensions,
                                            n_layers=n_layers,
                                            n_dim_per_layer=n_dim_per_layer,
                                            name="GP",
                                            activation=ACTIVATIONS,
                                            diffusivity_type=diffusivity_type)
    model = SDEApproximationNetwork(sde_model=encoder, method="euler")
    model.compile(optimizer=tf.keras.optimizers.Adamax())

    sde_i = SDEIdentification(model=model)
    
    return sde_i

# %%
def train_nd_model(n_dimensions, x_data_nd, y_data_nd, step_sizes_nd, sde_i, plot_history=False):
    hist = sde_i.train_model(x_data_nd, y_data_nd, step_size=step_sizes_nd,
                                 validation_split=VALIDATION_SPLIT, n_epochs=N_EPOCHS//n_dimensions, batch_size=BATCH_SIZE)

    if plot_history:
        fig, hist_axes = plt.subplots(1, 1, figsize=(10, 5))
        hist_axes.clear()
        hist_axes.plot(hist.history["loss"], label='loss')
        hist_axes.plot(hist.history["val_loss"], label='validation')
        hist_axes.legend()
        
        print(f"Training loss at ndim={n_dimensions}: {hist.history['loss'][-1]}")
        print(f"Validation loss at ndim={n_dimensions}: {hist.history['val_loss'][-1]}")
    
    return dict(loss=hist.history['loss'][-1], val_loss=hist.history['val_loss'][-1])

# %%
def evaluate_nd_model(n_dimensions, rng, print_results=False, increase_n_points=False):
    t0=time()
    x_data_nd, y_data_nd, step_sizes_nd = sample_nd_data(n_dimensions,
                                                         _rng=rng,
                                                         increase_n_points=increase_n_points)
    t1=time()
    sde_i_nd = define_nd_model(n_dimensions)
    t2=time()
    result_nd = train_nd_model(n_dimensions, x_data_nd, y_data_nd, step_sizes_nd, sde_i_nd, plot_history=print_results)
    t3=time()
    return result_nd, dict(time_sample=t1-t0, time_define=t2-t1, time_train=t3-t2), sde_i_nd

# %%
def results_to_dataframe(_loss, _time):
    df = pd.DataFrame(columns=["n_dimensions",
                               "n_iteration",
                               "loss",
                               "val_loss",
                               "time_sample",
                               "time_define",
                               "time_train"])
    for k in range(len(_loss)):
        dict_row = dict()
        loss_correction = 2*np.log(2*np.pi)/np.log(10)*_time[k]["n_dimensions"]
        dict_row["n_dimensions"] = _time[k]["n_dimensions"]
        dict_row["n_iteration"] = _time[k]["n_iteration"]
        dict_row["loss"] = _loss[k]["loss"] + loss_correction
        dict_row["val_loss"] = _loss[k]["val_loss"] + loss_correction
        dict_row["time_sample"] = _time[k]["time_sample"]
        dict_row["time_define"] = _time[k]["time_define"]
        dict_row["time_train"] = _time[k]["time_train"]
        df.loc[k] = dict_row
    return df

# %%
# run once to see if everything works as it should
rng = np.random.default_rng(random_seed)
result_loss, result_time, sde_i_model = evaluate_nd_model(n_dimensions=6,
                                                          rng=rng,
                                                          print_results=True,
                                                          increase_n_points=True)
# Out:
# training for 41 epochs with 54000 data points, validating with 6000
# The average loss for epoch 40 is -9.5779831657 Training loss at ndim=6: -9.57798316566295
# Validation loss at ndim=6: -9.572487497244568

# %%
# now run over multiple dimensions, multiple times
results_loss = []
results_time = []

n_iterations = 10  # iterations per dimension
for n_dimensions in np.arange(1, 20, 1):
    for n_iteration in np.arange(0, n_iterations):
        rng = np.random.default_rng(n_iteration+random_seed)

        result_loss, result_time, _ = evaluate_nd_model(n_dimensions=n_dimensions,
                                                        print_results=False,
                                                        rng=rng,
                                                        increase_n_points=False)
        result_time["n_iteration"] = n_iteration
        result_time["n_dimensions"] = n_dimensions
        results_loss.append(result_loss)
        results_time.append(result_time)
# Out:
# training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -1.5983028982 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -1.6143894425 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -1.6066356001 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -1.5937487959 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -1.6148811746 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -1.6119679779 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -1.6005153774 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -1.5921459950 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -1.5901075492 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -1.5971975329 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -3.2054691817 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -3.2121319477 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -3.2017427878 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -3.1874222883 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -3.2032189433 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -3.2187747982 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -3.1996871941 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -3.1878150828 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -3.2105749276 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -3.2067788223 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -4.8117990947 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -4.7914754859 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -4.7988522343 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -4.8079760932 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -4.8185070317 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -4.7958097057 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -4.8179619794 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -4.8183195636 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -4.8164622987 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -4.7892144542 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -6.4334456414 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -6.3981693965 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -6.4236743624 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -6.3995335748 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -6.4313742668 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -6.4348882258 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -6.4448257119 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -6.3994179220 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -6.4256939472 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -6.4285403971 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -8.0024121163 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -8.0153677632 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -8.0203418350 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -8.0438964980 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -8.0527357804 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -8.0093583739 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -8.0250466977 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -8.0198198738 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -8.0424940275 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -7.9790247096 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -9.6301583134 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -9.6000974243 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -9.6227814021 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -9.6354941609 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -9.6315173186 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -9.6217247412 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -9.6339381057 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -9.6021268578 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -9.5336813804 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -9.6206407750 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -11.2226495090 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -11.1013035289 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -11.1485390620 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -11.2125934818 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -11.1889542458 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -11.1488528129 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -11.1961922832 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -11.1374756641 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -11.1957023535 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -11.0914771404 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -12.8133739550 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -12.7968216874 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -12.6786368401 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -12.7244402320 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -12.7895785850 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -12.7234959555 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -12.7072699903 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -12.7814378765 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -12.7236286694 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -12.6897810181 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -14.2617145674 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -14.2771569835 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -14.2856256529 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -14.3179020171 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -14.3370853581 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -14.2652168308 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -14.2149310136 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -14.3532934688 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -14.3007227980 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -14.2935423333 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -15.7413893959 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -15.8497763199 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -15.7902979769 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -15.8186347803 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -15.8014204803 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -15.8214953381 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -15.8017867497 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -15.8258567603 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -15.8420613111 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -15.8077963116 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -17.2738184674 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -17.2825670495 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -17.4550656466 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -17.3101164633 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -17.3759894687 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -17.2520098859 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -17.2130549103 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -17.4536798335 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -17.3118706303 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -17.3433202589 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -18.8655241263 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -18.7992809756 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -18.9350603698 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -18.8387369888 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -18.8680534697 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -18.7826173872 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -18.8153400310 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -18.7190269917 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -18.7453938663 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -18.7134532384 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -20.4690864997 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -20.3363915470 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -20.3512071401 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -20.2873183686 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -20.3779290348 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -20.1180491710 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -20.3285371613 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -20.2949355769 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -20.4211239115 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -20.3017853901 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -21.8076653335 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -21.9101278702 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -21.7684256140 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -21.6812231542 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -21.9049887299 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -21.7502517459 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -21.7738828662 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -21.7847244360 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -21.8450214327 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -21.7944729295 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -23.2127091653 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -23.3158750696 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -23.2679906052 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -23.2831145187 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -23.2114141220 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -23.2080195819 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -23.1837374828 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -23.1667462366 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -23.3267062715 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -23.3571891486 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -24.6051820438 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -24.6480359889 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -24.7020029640 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -24.6215574247 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -24.5932817941 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -24.5679288168 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -24.5563477119 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -24.8183140369 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -24.6247041501 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -24.7528237304 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -26.2908032963 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -26.2767804071 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -26.1925220688 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -26.2263575920 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -26.4399844630 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -26.2662802326 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -26.1926446580 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -26.1201139615 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -26.1457547887 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -26.3166091380 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -27.8441160724 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -27.4456500079 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -27.5025831937 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -27.7807615060 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -27.6851758128 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -27.7404616757 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -27.6457528655 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -27.6710014594 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -27.6805010719 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -27.5139355382 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -29.2366620359 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -29.0215094880 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -29.0027751146 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -29.0984513996 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -29.0527826034 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -28.9494931695 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -29.1898617624 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -29.0857126415 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -29.0340284102 training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -28.9451211199

# %%
df = results_to_dataframe(results_loss, results_time)
df.to_csv('figures/fullrun_n_iteration10_n_dimensions_1to20.csv')

data_mean = [np.mean(k["loss"]) for (_,k) in df.groupby("n_dimensions")]
data_std = [np.mean(k["loss"]) for (_,k) in df.groupby("n_dimensions")]
data_mean_val = [np.mean(k["val_loss"]) for (_,k) in df.groupby("n_dimensions")]
data_std_val = [np.mean(k["val_loss"]) for (_,k) in df.groupby("n_dimensions")]
data_idx = np.arange(1, len(data_mean)+1)

fig, ax = plt.subplots(1, 1, figsize=(5, 3))
ax.scatter(df["n_dimensions"], df["loss"], s=1,color="blue", label="Training")
ax.scatter(df["n_dimensions"], df["val_loss"], s=1, color="orange", label="Validation")
ax.plot(data_idx, data_mean, color="blue")
ax.plot(data_idx, data_mean_val, color="orange")
ax.set_xticks(np.arange(1, 20, 2));
ax.set_xlabel("Dimensions")
ax.set_ylabel("Normalized loss")
ax.legend()
fig.tight_layout()

fig.savefig("figures/fullrun_n_iteration10_n_dimensions_1to20.pdf")
fig.savefig("figures/fullrun_n_iteration10_n_dimensions_1to20.png")

# %%
print(2*np.log(2*np.pi)/np.log(10)*7)
# Out:
# 11.174518157013608

# %%
rng = np.random.default_rng(random_seed)

x_data_nd, y_data_nd, step_sizes_nd = sample_nd_data(n_dimensions=6, _rng=rng)
ax = plot_results_functions(sde_i_model.drift_diffusivity, true_drift_diffusivity,
                            x_data_nd, y_data_nd, rng,
                            data_transform_network=None,
                            data_transform_true=None)

# %%
# now, try the same but with an increasing number of points
results_loss2 = []
results_time2 = []

n_iterations = 1  # iterations per dimension
for n_dimensions in np.arange(1, 20, 5):
    for n_iteration in np.arange(0, n_iterations):
        t0=time()
        rng = np.random.default_rng(n_iteration+random_seed)

        result_loss, result_time, _ = evaluate_nd_model(n_dimensions=n_dimensions,
                                                        print_results=False,
                                                        rng=rng,
                                                        increase_n_points=True)
        print(f"dim={n_dimensions}, iter={n_iteration} took {time()-t0} seconds.")
        result_time["n_iteration"] = n_iteration
        result_time["n_dimensions"] = n_dimensions
        results_loss2.append(result_loss)
        results_time2.append(result_time)

df2 = results_to_dataframe(results_loss2, results_time2)
file2 = 'figures/fullrun_n_iteration10_n_dimensions_1to20_newpoints.csv'
df2.to_csv(file2)
# Out:
# training for 250 epochs with 9000 data points, validating with 1000
# The average loss for epoch 249 is -1.5984408614 dim=1, iter=0 took 55.988263845443726 seconds.
# training for 41 epochs with 54000 data points, validating with 6000
# The average loss for epoch 40 is -9.5640513740 dim=6, iter=0 took 67.12762379646301 seconds.
# training for 22 epochs with 99000 data points, validating with 11000
# The average loss for epoch 21 is -17.0943544199 dim=11, iter=0 took 75.26033782958984 seconds.

# %%
df2 = pd.read_csv(file2)

data_mean = [np.mean(k["loss"]) for (_,k) in df2.groupby("n_dimensions")]
data_std = [np.mean(k["loss"]) for (_,k) in df2.groupby("n_dimensions")]
data_mean_val = [np.mean(k["val_loss"]) for (_,k) in df2.groupby("n_dimensions")]
data_std_val = [np.mean(k["val_loss"]) for (_,k) in df2.groupby("n_dimensions")]
data_idx = np.arange(1, len(data_mean)+1)

fig, ax = plt.subplots(1, 1, figsize=(5, 3))
ax.scatter(df2["n_dimensions"], df2["loss"], s=1,color="blue", label="Training")
ax.scatter(df2["n_dimensions"], df2["val_loss"], s=1, color="orange", label="Validation")
#ax.plot(data_idx, data_mean, color="blue")
#ax.plot(data_idx, data_mean_val, color="orange")
ax.set_xticks(np.arange(1, 20, 2));
ax.set_xlabel("Dimensions")
ax.set_ylabel("Normalized loss")
ax.legend()
fig.tight_layout()

fig.savefig("figures/fullrun_n_iteration10_n_dimensions_1to20_newpoints.pdf")
fig.savefig("figures/fullrun_n_iteration10_n_dimensions_1to20_newpoints.png")
